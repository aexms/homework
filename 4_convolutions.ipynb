# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'E:/data/notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset'][:16500] # with bigger test set it does not work
  test_labels = save['test_labels'][:16500] # not enough resources
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (16500, 28, 28) (16500,)

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (16500, 28, 28, 1) (16500, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.153305
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.783982
# Minibatch accuracy: 18.8%
# Validation accuracy: 46.3%
# Minibatch loss at step 100: 0.934313
# Minibatch accuracy: 62.5%
# Validation accuracy: 67.8%
# Minibatch loss at step 150: 0.518359
# Minibatch accuracy: 81.2%
# Validation accuracy: 74.7%
# Minibatch loss at step 200: 0.728090
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.5%
# Minibatch loss at step 250: 1.193982
# Minibatch accuracy: 50.0%
# Validation accuracy: 77.0%
# Minibatch loss at step 300: 0.411316
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.5%
# Minibatch loss at step 350: 0.587300
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.2%
# Minibatch loss at step 400: 0.306305
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.2%
# Minibatch loss at step 450: 0.762330
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.8%
# Minibatch loss at step 500: 0.641760
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.8%
# Minibatch loss at step 550: 0.863441
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.8%
# Minibatch loss at step 600: 0.283546
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.6%
# Minibatch loss at step 650: 0.912761
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.3%
# Minibatch loss at step 700: 0.975159
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.3%
# Minibatch loss at step 750: 0.047941
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.1%
# Minibatch loss at step 800: 0.602986
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.6%
# Minibatch loss at step 850: 1.033514
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
# Minibatch loss at step 900: 0.671146
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.3%
# Minibatch loss at step 950: 0.647411
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.2%
# Minibatch loss at step 1000: 0.440105
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.7%
# Test accuracy: 89.3%

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 2001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.663411
# Minibatch accuracy: 12.5%
# Validation accuracy: 13.6%
# Minibatch loss at step 50: 1.219479
# Minibatch accuracy: 75.0%
# Validation accuracy: 57.0%
# Minibatch loss at step 100: 0.942186
# Minibatch accuracy: 56.2%
# Validation accuracy: 63.7%
# Minibatch loss at step 150: 0.536156
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.1%
# Minibatch loss at step 200: 0.794957
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.2%
# Minibatch loss at step 250: 1.237723
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.6%
# Minibatch loss at step 300: 0.294208
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 350: 0.551857
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.1%
# Minibatch loss at step 400: 0.342250
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.9%
# Minibatch loss at step 450: 0.711670
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.6%
# Minibatch loss at step 500: 0.701261
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.1%
# Minibatch loss at step 550: 0.915537
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.5%
# Minibatch loss at step 600: 0.368833
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.8%
# Minibatch loss at step 650: 0.963786
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.9%
# Minibatch loss at step 700: 1.063008
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.5%
# Minibatch loss at step 750: 0.049645
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.5%
# Minibatch loss at step 800: 0.605686
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
# Minibatch loss at step 850: 0.831363
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.6%
# Minibatch loss at step 900: 0.602481
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
# Minibatch loss at step 950: 0.518758
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.1%
# Minibatch loss at step 1000: 0.212109
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.4%
# Minibatch loss at step 1050: 0.482171
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.1%
# Minibatch loss at step 1100: 0.572619
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.6%
# Minibatch loss at step 1150: 0.485300
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 1200: 0.906173
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.6%
# Minibatch loss at step 1250: 0.745409
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.0%
# Minibatch loss at step 1300: 0.304884
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.5%
# Minibatch loss at step 1350: 0.843281
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.2%
# Minibatch loss at step 1400: 0.307442
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.1%
# Minibatch loss at step 1450: 0.217274
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.5%
# Minibatch loss at step 1500: 0.724861
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.1%
# Minibatch loss at step 1550: 0.510430
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.6%
# Minibatch loss at step 1600: 0.749718
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.3%
# Minibatch loss at step 1650: 0.691041
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.1%
# Minibatch loss at step 1700: 0.547675
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.7%
# Minibatch loss at step 1750: 0.584886
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.6%
# Minibatch loss at step 1800: 0.291409
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.5%
# Minibatch loss at step 1850: 0.698252
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 1900: 0.326423
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 1950: 0.635652
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.3%
# Minibatch loss at step 2000: 0.089693
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.0%
# Test accuracy: 92.3%

# %%
#added dropout and L2 reg

batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64
beta = 0.0005

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.dropout(tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases), 0.8)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  l2_reg = tf.nn.l2_loss(layer1_weights) + tf.nn.l2_loss(layer2_weights) + tf.nn.l2_loss(layer3_weights) + tf.nn.l2_loss(layer4_weights)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
  loss += beta * l2_reg  
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 2001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.893486
# Minibatch accuracy: 12.5%
# Validation accuracy: 9.0%
# Minibatch loss at step 50: 1.861290
# Minibatch accuracy: 25.0%
# Validation accuracy: 38.8%
# Minibatch loss at step 100: 1.146555
# Minibatch accuracy: 62.5%
# Validation accuracy: 62.2%
# Minibatch loss at step 150: 0.812204
# Minibatch accuracy: 75.0%
# Validation accuracy: 72.3%
# Minibatch loss at step 200: 1.062445
# Minibatch accuracy: 62.5%
# Validation accuracy: 74.3%
# Minibatch loss at step 250: 1.205442
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.4%
# Minibatch loss at step 300: 0.599029
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.9%
# Minibatch loss at step 350: 0.967532
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.0%
# Minibatch loss at step 400: 0.475818
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.8%
# Minibatch loss at step 450: 1.037401
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.2%
# Minibatch loss at step 500: 0.934738
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.4%
# Minibatch loss at step 550: 0.929640
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.7%
# Minibatch loss at step 600: 0.490012
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.9%
# Minibatch loss at step 650: 0.923606
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.1%
# Minibatch loss at step 700: 1.130517
# Minibatch accuracy: 56.2%
# Validation accuracy: 81.3%
# Minibatch loss at step 750: 0.172858
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.9%
# Minibatch loss at step 800: 0.727142
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.8%
# Minibatch loss at step 850: 0.871185
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.0%
# Minibatch loss at step 900: 0.679390
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.2%
# Minibatch loss at step 950: 0.719052
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.8%
# Minibatch loss at step 1000: 0.387156
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.4%
# Minibatch loss at step 1050: 0.837597
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.8%
# Minibatch loss at step 1100: 0.797283
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.2%
# Minibatch loss at step 1150: 0.702664
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.4%
# Minibatch loss at step 1200: 1.260417
# Minibatch accuracy: 50.0%
# Validation accuracy: 82.6%
# Minibatch loss at step 1250: 0.554713
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.9%
# Minibatch loss at step 1300: 0.546306
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.4%
# Minibatch loss at step 1350: 1.092002
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.4%
# Minibatch loss at step 1400: 0.482335
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Minibatch loss at step 1450: 0.579788
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.4%
# Minibatch loss at step 1500: 0.755462
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.4%
# Minibatch loss at step 1550: 0.777469
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.4%
# Minibatch loss at step 1600: 1.193120
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.1%
# Minibatch loss at step 1650: 0.710829
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.9%
# Minibatch loss at step 1700: 0.875434
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.7%
# Minibatch loss at step 1750: 0.578945
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.6%
# Minibatch loss at step 1800: 0.429164
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.7%
# Minibatch loss at step 1850: 0.927158
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.3%
# Minibatch loss at step 1900: 0.364561
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.9%
# Minibatch loss at step 1950: 0.727546
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.8%
# Minibatch loss at step 2000: 0.263785
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.4%
# Test accuracy: 89.8%
