# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'originated']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.850749
# Nearest to so: terminate, fronted, poul, oran, lfflin, hybridized, slashed, constructor,
# Nearest to when: roused, each, generative, names, hereford, deny, correct, ligament,
# Nearest to united: preyed, thurston, folding, summarily, desecration, krag, rewarding, generalised,
# Nearest to at: gazeta, conspiracies, filthy, partisan, subgenus, expecting, gamble, times,
# Nearest to three: analogue, overtly, durrell, hira, willow, collections, commonwealth, indoctrination,
# Nearest to but: sediments, asterism, lehi, ruble, masse, olof, hasidism, ece,
# Nearest to two: convicts, vibrating, sindhu, riga, empowered, solidified, savoie, jehoahaz,
# Nearest to have: hemispheres, manometer, injurious, flagellate, rader, lint, streetcars, civic,
# Nearest to system: aged, intruder, football, squadrons, japanese, peloponnesus, prejudices, psychopathic,
# Nearest to history: legume, diffeomorphic, throw, agreed, carmelite, shaped, underdog, attractors,
# Nearest to zero: sailing, diagonals, tcp, acclaimed, bodkin, volkov, commandants, executor,
# Nearest to were: enhancements, repetitive, square, xa, sweetened, challengers, website, hultsfred,
# Nearest to states: girth, divergent, weighed, galtieri, aphorisms, saltzer, sue, golems,
# Nearest to been: capitulated, degenerated, y, begining, frequented, sous, waldo, chording,
# Nearest to all: trans, hideki, ecclesiastes, wta, ned, mpc, newsweek, equivalency,
# Nearest to in: gopher, savior, babcock, indecisive, mandy, volunteering, famously, doings,
# Average loss at step 2000: 4.360239
# Average loss at step 4000: 3.864751
# Average loss at step 6000: 3.794486
# Average loss at step 8000: 3.687891
# Average loss at step 10000: 3.617587
# Nearest to so: where, skilling, kore, serre, lfflin, poul, penetrates, became,
# Nearest to when: roused, solace, shift, names, contains, dilute, had, griff,
# Nearest to united: extracellular, congregationalism, desecration, folding, martial, kitten, robin, kola,
# Nearest to at: gazeta, in, during, speciation, lemy, edifices, filthy, after,
# Nearest to three: six, seven, four, five, two, eight, nine, zero,
# Nearest to but: although, prediction, wade, sediments, spake, briefly, husk, favorites,
# Nearest to two: three, five, six, four, seven, eight, one, zero,
# Nearest to have: be, had, has, are, were, consulate, chisinau, consequent,
# Nearest to system: football, aged, japanese, hahnemann, peloponnesus, intruder, sporadic, hindrance,
# Nearest to history: city, legume, latter, diffeomorphic, stahl, steels, shaped, intramolecular,
# Nearest to zero: eight, five, seven, four, nine, six, three, two,
# Nearest to were: are, was, have, is, been, pledges, weary, liffey,
# Nearest to states: saltzer, weighed, billy, golems, divergent, abeyance, bloodline, particles,
# Nearest to been: capitulated, be, sous, were, rivals, crossover, discoveries, by,
# Nearest to all: ned, strategy, skelton, like, handicap, mutinies, treasurer, valdes,
# Nearest to in: of, on, naturalised, jima, at, with, from, within,
# Average loss at step 12000: 3.610686
# Average loss at step 14000: 3.571611
# Average loss at step 16000: 3.412596
# Average loss at step 18000: 3.458022
# Average loss at step 20000: 3.541416
# Nearest to so: novak, only, televised, timorese, winfrey, where, poul, storyteller,
# Nearest to when: if, where, structuralist, because, navier, solace, was, since,
# Nearest to united: extracellular, desecration, martial, congregationalism, rorty, kitten, city, robin,
# Nearest to at: in, on, within, during, from, with, and, after,
# Nearest to three: four, six, seven, two, five, eight, nine, zero,
# Nearest to but: although, ostensibly, does, however, that, and, if, which,
# Nearest to two: three, five, four, six, eight, seven, one, zero,
# Nearest to have: had, has, be, are, were, consulate, chisinau, jojo,
# Nearest to system: aged, football, lowly, sporadic, hahnemann, japanese, squadrons, busch,
# Nearest to history: legume, city, latter, steels, end, shaped, mut, oa,
# Nearest to zero: five, six, seven, four, three, eight, two, nine,
# Nearest to were: are, was, had, have, been, pledges, be, inconsistently,
# Nearest to states: golems, bloodline, saltzer, weighed, billy, divergent, acquisitions, blackjack,
# Nearest to been: be, capitulated, become, were, was, being, discoveries, by,
# Nearest to all: these, strategy, many, those, ned, provincia, several, handicap,
# Nearest to in: at, on, with, during, overturned, from, within, polygons,
# Average loss at step 22000: 3.502806
# Average loss at step 24000: 3.490731
# Average loss at step 26000: 3.483660
# Average loss at step 28000: 3.478196
# Average loss at step 30000: 3.506105
# Nearest to so: winfrey, timorese, poul, titanic, beagles, very, more, notations,
# Nearest to when: if, because, where, after, before, during, though, although,
# Nearest to united: extracellular, city, desecration, congregationalism, kitten, supreme, rorty, folding,
# Nearest to at: in, during, within, under, jettisoned, modems, until, harrington,
# Nearest to three: four, five, seven, eight, two, six, nine, zero,
# Nearest to but: although, however, and, though, xt, which, are, if,
# Nearest to two: four, three, one, five, seven, six, eight, zero,
# Nearest to have: had, has, are, were, be, say, remove, contiguous,
# Nearest to system: lowly, benny, jaynes, aged, busch, harwich, sporadic, dominion,
# Nearest to history: city, legume, segmented, latter, list, intramolecular, polluted, eclipsed,
# Nearest to zero: five, four, seven, eight, six, three, nine, two,
# Nearest to were: are, was, had, have, been, pledges, uplink, include,
# Nearest to states: golems, bloodline, paisiello, blackjack, dabbled, billy, acquisitions, luton,
# Nearest to been: be, become, was, capitulated, were, had, already, pupils,
# Nearest to all: these, some, many, strategy, provincia, those, several, handicap,
# Nearest to in: at, during, on, since, within, of, overturned, and,
# Average loss at step 32000: 3.503829
# Average loss at step 34000: 3.497656
# Average loss at step 36000: 3.456291
# Average loss at step 38000: 3.301779
# Average loss at step 40000: 3.435155
# Nearest to so: ambiguous, winfrey, more, televised, fronted, compound, gerrymandering, timorese,
# Nearest to when: if, before, while, after, where, although, because, during,
# Nearest to united: supreme, extracellular, rorty, kitten, folding, desecration, executive, generalised,
# Nearest to at: during, on, within, augsburg, in, disqualified, couper, soliloquy,
# Nearest to three: two, four, seven, six, five, eight, nine, one,
# Nearest to but: however, although, and, though, while, are, xt, rationally,
# Nearest to two: three, four, seven, five, six, eight, one, nine,
# Nearest to have: had, has, were, are, be, bentley, remove, holistic,
# Nearest to system: jaynes, lowly, systems, harwich, pacing, aurelius, simulcast, bx,
# Nearest to history: legume, liturgical, segmented, liquidity, city, itv, polluted, eclipsed,
# Nearest to zero: five, seven, nine, eight, four, two, three, six,
# Nearest to were: are, have, was, had, uplink, these, while, been,
# Nearest to states: kingdom, golems, bloodline, paisiello, dari, blackjack, nations, accrue,
# Nearest to been: become, be, was, already, capitulated, were, discoveries, being,
# Nearest to all: these, both, some, several, many, strategy, handicap, those,
# Nearest to in: from, and, of, during, deliriants, on, with, infimum,
# Average loss at step 42000: 3.435276
# Average loss at step 44000: 3.450293
# Average loss at step 46000: 3.452804
# Average loss at step 48000: 3.353989
# Average loss at step 50000: 3.381592
# Nearest to so: if, then, reverts, profitable, engined, serre, winfrey, storyteller,
# Nearest to when: if, while, after, where, before, although, but, though,
# Nearest to united: extracellular, supreme, rorty, city, generalised, shostakovich, folding, fuchs,
# Nearest to at: during, on, in, under, toward, desmodromic, edifices, modems,
# Nearest to three: four, six, two, five, seven, eight, nine, one,
# Nearest to but: however, although, though, while, when, and, pinch, that,
# Nearest to two: three, six, four, one, seven, five, eight, nine,
# Nearest to have: had, has, be, were, are, remove, bentley, relieving,
# Nearest to system: jaynes, systems, busch, aurelius, bingham, piast, pacing, binary,
# Nearest to history: liturgical, legume, list, wolfhound, enabled, packer, shaped, residuals,
# Nearest to zero: five, eight, seven, four, six, nine, two, three,
# Nearest to were: are, was, have, had, be, been, pledges, although,
# Nearest to states: kingdom, golems, bloodline, nations, dabbled, luton, petn, pulleys,
# Nearest to been: become, was, be, already, were, capitulated, lefebvre, being,
# Nearest to all: many, both, these, some, faith, handicap, any, kyrenia,
# Nearest to in: during, within, since, on, from, of, until, between,
# Average loss at step 52000: 3.433266
# Average loss at step 54000: 3.426041
# Average loss at step 56000: 3.437829
# Average loss at step 58000: 3.398297
# Average loss at step 60000: 3.394085
# Nearest to so: if, timorese, then, serre, beagles, profitable, even, sometimes,
# Nearest to when: if, while, after, before, although, because, where, during,
# Nearest to united: supreme, extracellular, rorty, fuchs, shostakovich, generalised, county, speculators,
# Nearest to at: during, toward, in, clav, under, soliloquy, after, within,
# Nearest to three: five, four, six, eight, seven, two, nine, zero,
# Nearest to but: however, although, and, though, while, than, when, nevertheless,
# Nearest to two: three, five, four, one, six, eight, seven, zero,
# Nearest to have: had, has, are, be, were, include, oats, produce,
# Nearest to system: systems, jaynes, binary, pacing, lowly, rehearsal, harwich, busch,
# Nearest to history: philosophy, demographics, sciences, liturgical, definitional, list, age, seventh,
# Nearest to zero: five, four, seven, eight, six, three, nine, two,
# Nearest to were: are, was, had, have, while, although, those, including,
# Nearest to states: kingdom, nations, countries, bloodline, dabbled, factorial, golems, protocols,
# Nearest to been: become, be, already, capitulated, was, were, had, lefebvre,
# Nearest to all: many, some, any, various, those, these, several, both,
# Nearest to in: during, since, within, of, from, including, throughout, across,
# Average loss at step 62000: 3.234648
# Average loss at step 64000: 3.255300
# Average loss at step 66000: 3.400004
# Average loss at step 68000: 3.394989
# Average loss at step 70000: 3.356355
# Nearest to so: then, if, sometimes, timorese, lonely, serre, spectacle, profitable,
# Nearest to when: if, while, before, although, after, where, because, was,
# Nearest to united: supreme, rorty, extracellular, outside, desecration, fuchs, shostakovich, ardennes,
# Nearest to at: during, in, dru, under, clav, within, edifices, inuktitut,
# Nearest to three: four, six, five, two, seven, eight, nine, zero,
# Nearest to but: however, although, though, which, while, and, nevertheless, that,
# Nearest to two: three, six, four, one, five, seven, eight, zero,
# Nearest to have: had, has, were, are, be, having, contain, include,
# Nearest to system: systems, c, jaynes, pacing, harwich, rehearsal, bicyclists, menthol,
# Nearest to history: list, philosophy, literature, period, liturgical, residuals, demographics, sciences,
# Nearest to zero: five, eight, four, six, seven, nine, two, three,
# Nearest to were: are, was, have, had, be, been, although, pledges,
# Nearest to states: kingdom, nations, countries, factorial, things, actresses, bloodline, branch,
# Nearest to been: become, be, was, already, were, had, recently, previously,
# Nearest to all: many, some, any, various, both, every, provincia, thousands,
# Nearest to in: within, during, on, since, throughout, for, among, at,
# Average loss at step 72000: 3.375953
# Average loss at step 74000: 3.350952
# Average loss at step 76000: 3.312297
# Average loss at step 78000: 3.351047
# Average loss at step 80000: 3.377477
# Nearest to so: then, if, serre, reverts, sometimes, rigging, lonely, timorese,
# Nearest to when: if, before, after, while, although, where, during, though,
# Nearest to united: supreme, rorty, extracellular, shostakovich, desecration, fuchs, speculators, jokingly,
# Nearest to at: in, during, modems, within, edifices, resistivity, on, kitzmiller,
# Nearest to three: six, four, five, seven, two, eight, nine, one,
# Nearest to but: however, although, nevertheless, while, though, bowled, and, see,
# Nearest to two: three, six, five, four, seven, one, eight, zero,
# Nearest to have: had, has, are, were, be, include, having, contain,
# Nearest to system: systems, pacing, jaynes, menthol, program, service, rehearsal, code,
# Nearest to history: list, residuals, liturgical, violating, coherent, philosophy, pages, skill,
# Nearest to zero: seven, five, eight, six, four, nine, three, two,
# Nearest to were: are, was, have, had, been, those, be, although,
# Nearest to states: kingdom, nations, countries, us, factorial, bloodline, marino, positives,
# Nearest to been: become, be, were, already, was, recently, had, previously,
# Nearest to all: many, both, every, any, some, various, thousands, several,
# Nearest to in: during, within, until, on, at, under, since, around,
# Average loss at step 82000: 3.406735
# Average loss at step 84000: 3.413097
# Average loss at step 86000: 3.393807
# Average loss at step 88000: 3.351238
# Average loss at step 90000: 3.365082
# Nearest to so: if, serre, reverts, timorese, evangelion, too, rigging, sometimes,
# Nearest to when: while, if, before, where, after, although, since, during,
# Nearest to united: supreme, rorty, extracellular, shostakovich, fuchs, jokingly, desecration, outside,
# Nearest to at: during, on, under, edifices, in, near, around, neglects,
# Nearest to three: five, four, two, eight, seven, six, nine, one,
# Nearest to but: however, and, although, nevertheless, which, though, while, until,
# Nearest to two: three, five, four, eight, seven, six, one, nine,
# Nearest to have: had, has, were, be, are, having, include, contain,
# Nearest to system: systems, pacing, program, model, jaynes, network, rehearsal, bicyclists,
# Nearest to history: list, literature, liturgical, violating, residuals, period, coherent, basketball,
# Nearest to zero: eight, five, seven, six, nine, four, three, two,
# Nearest to were: are, had, was, have, while, although, became, pledges,
# Nearest to states: kingdom, nations, us, countries, factorial, bloodline, state, actresses,
# Nearest to been: become, be, already, was, previously, wanda, recently, had,
# Nearest to all: many, both, some, several, various, every, these, thousands,
# Nearest to in: within, during, under, since, at, until, around, near,
# Average loss at step 92000: 3.399627
# Average loss at step 94000: 3.253399
# Average loss at step 96000: 3.359750
# Average loss at step 98000: 3.245342
# Average loss at step 100000: 3.360558
# Nearest to so: serre, if, then, reverts, thus, timorese, sometimes, calm,
# Nearest to when: if, while, although, before, where, after, though, because,
# Nearest to united: supreme, rorty, speculators, outside, fuchs, extracellular, confederate, shostakovich,
# Nearest to at: during, in, on, within, under, after, kitzmiller, quadrangle,
# Nearest to three: four, six, five, two, seven, eight, nine, one,
# Nearest to but: however, although, and, though, while, which, where, elmore,
# Nearest to two: three, four, six, five, seven, eight, one, nine,
# Nearest to have: had, has, were, are, be, include, having, contain,
# Nearest to system: systems, pacing, model, jaynes, program, network, observing, bicyclists,
# Nearest to history: list, literature, definitional, coherent, violating, planetary, pages, legume,
# Nearest to zero: five, seven, eight, four, six, nine, three, two,
# Nearest to were: are, was, have, these, include, had, although, became,
# Nearest to states: kingdom, nations, countries, us, bloodline, state, factorial, marino,
# Nearest to been: become, be, already, was, recently, previously, wanda, grown,
# Nearest to all: many, some, these, several, every, various, both, any,
# Nearest to in: during, within, on, at, throughout, until, near, from,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
